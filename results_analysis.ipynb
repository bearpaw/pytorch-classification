# %%
# %matplotlib notebook
import utils

# %% [markdown]
# Next Experiments:
# - Baseline at LR=0.005, no decay
# - Rerun shake-it experiment

# %%
utils.plot_results(['baseline', 'lr 0.005, geolr', 'lr 0.01, geolr'], 'cifar10', 'resnet-110')
# Out:
# <img src="data:image/png;base64,..." width="999.9999628438592">

# %%
utils.plot_results(['baseline', 'lr 0.005, geolr', 'lr 0.01, geolr'], 'cifar10', 'vgg19_bn')
# Out:
# <img src="data:image/png;base64,..." width="999.9999628438592">

# %%
utils.plot_results(['baseline', 'lr 0.005, geolr', 'lr 0.01, geolr'], 'cifar100', 'resnet-110')
# Out:
# <img src="data:image/png;base64,..." width="999.9999628438592">

# %%
utils.plot_results(['baseline', 'lr 0.005, geolr', 'lr 0.01, geolr'], 'cifar100', 'vgg19_bn')
# Out:
# <img src="data:image/png;base64,..." width="999.9999628438592">

# %%
utils.plot_results(['baseline', 'lr 0.005,blended', 'lr 0.005, geolr'], 'cifar100', 'vgg19_bn')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
utils.plot_results(['baseline', 'lr 0.005,blended'], 'cifar100', 'densenet-bc-100-12')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
utils.plot_results(['baseline', 'lr 0.005, exp-disc-geolr', 'lr 0.005, geolr'], 'cifar10', 'vgg19_bn')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
utils.plot_results(['baseline', 'shake-it', 'lr 0.005, geolr'], 'cifar10', 'vgg19_bn')
# Out:
# <img src="data:image/png;base64,..." width="1000">
